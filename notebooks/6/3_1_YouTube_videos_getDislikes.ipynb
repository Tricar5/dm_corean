# %%
# 13.1 Дизлайки
# Пакеты для генерирования случайного числа, обращения по интересующему URL-адресу и "засыпания" исполнения соответственно
import random, requests, time

import pandas as pd

# Параметры для маскировки алгоритмического запроса под запрос обычного пользователя
# proxyArray = ["http://s5nsnf:1bU8z2@91.188.241.218:9773"]

userAgent = ["Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 RuxitSynthetic/1.0 v3653660536 t3060034875834570496 ath318f403d altpub cvcv=2 smf=0",
             "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 RuxitSynthetic/1.0 v7638580655095651333 t3369586550842097326 ath1fb31b7a altpriv cvcv=2 smf=0",
             "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 RuxitSynthetic/1.0 v4022270135305624536 t210370085878917362 ath259cea6f altpriv cvcv=2 smf=0",
             "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36 RuxitSynthetic/1.0 v1605625219501687423 t5534040873462942519 ath5ee645e0 altpriv cvcv=2 smf=0",
             "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36 RuxitSynthetic/1.0 v9045054735720176711 t8055053424576152628 ath4b3726d5 altpriv cvcv=2 smf=0",
             "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 RuxitSynthetic/1.0 v4774994596211760778 t5534040873462942519 ath5ee645e0 altpriv cvcv=2 smf=0",
             "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 RuxitSynthetic/1.0 v1418982706 t79976092658796286 athfa3c3975 altpub cvcv=2 smf=0",
             "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 RuxitSynthetic/1.0 v4650801409596051110 t3369586550842097326 ath1fb31b7a altpriv cvcv=2 smf=0"
            ]

# Определение авторской функции
def getDislikes(videoId, likeCount = None):
    url = "https://returnyoutubedislikeapi.com/votes?videoId=" + videoId
    
    if likeCount != None:
        url.append("&likeCount=" + str(likeCount))
        
    # randomProxy = random.choice(proxyArray)
    # proxyDict = { 
    #       "http"  : randomProxy, 
    #       "https" : randomProxy, 
    # }
    
    headers = {
      'authority': 'returnyoutubedislikeapi.com',
      'cache-control': 'max-age=0',
      'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Microsoft Edge";v="98"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'upgrade-insecure-requests': '1',
      'user-agent': random.choice(userAgent),
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
      'sec-fetch-site': 'none',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-user': '?1',
      'sec-fetch-dest': 'document',
      'accept-language': 'ru,en;q=0.9,en-GB;q=0.8,en-US;q=0.7'
    }
    
    response = requests.request("GET", url, headers=headers) # , proxies=proxyDict
    return response.json()['dislikes']

# Применение авторской функции (вставить в неё id интересующего видео в качестве аргумента) 
getDislikes('yCGvQb3CL2c')
# Out:
# 67

# %%
import pandas as pd
videos_df = pd.read_excel('/Users/andrey/PycharmProjects/DataMiningProjects/data/seminar5/k beauty_Video_characteristics.xlsx')

# %%
# 13.2 Дизлайки. Цикл. Первичный
indeseS = videos_df.index
errorS = []
for j in indeseS:
    time.sleep(1)
    print(f'Строка №{j}')
    try:
        videos_df.loc[j, "statistics.dislikesCount"] = getDislikes(videos_df['id'][j])
    except:
        print(f'Ошибка в строке {j}')
        errorS.append(j)
# Out:
# Строка №0
# Строка №1
# Строка №2
# Строка №3
# Строка №4
# Строка №5
# Строка №6
# Строка №7
# Строка №8
# Строка №9
# Строка №10
# Строка №11
# Строка №12
# Строка №13
# Строка №14
# Строка №15
# Строка №16
# Строка №17
# Строка №18
# Строка №19
# Строка №20
# Строка №21
# Строка №22
# Строка №23
# Строка №24
# Строка №25
# Строка №26
# Строка №27
# Строка №28
# Строка №29
# Строка №30
# Строка №31
# Строка №32
# Строка №33
# Строка №34
# Строка №35
# Строка №36
# Строка №37
# Строка №38
# Строка №39
# Строка №40
# Строка №41
# Строка №42
# Строка №43
# Строка №44
# Строка №45
# Строка №46
# Строка №47
# Строка №48
# Строка №49
# Строка №50
# Строка №51
# Строка №52
# Строка №53
# Строка №54
# Строка №55
# Строка №56
# Строка №57
# Строка №58
# Строка №59
# Строка №60
# Строка №61
# Строка №62
# Строка №63
# Строка №64
# Строка №65
# Строка №66
# Строка №67
# Строка №68
# Строка №69
# Строка №70
# Строка №71
# Строка №72
# Строка №73
# Строка №74
# Строка №75
# Строка №76
# Строка №77
# Строка №78
# Строка №79
# Строка №80
# Строка №81
# Строка №82
# Строка №142
# Строка №143
# Строка №144
# Строка №145
# Строка №146
# Строка №147
# Строка №148
# Строка №149
# Строка №150
# Строка №151
# Строка №152
# Строка №153
# Строка №154
# Строка №155
# Строка №156
# Строка №157
# Строка №158
# Строка №159
# Строка №160
# Строка №161
# Строка №162
# Строка №163
# Строка №164
# Строка №165
# Строка №166
# Строка №167
# Строка №168
# Строка №169
# Строка №170
# Строка №171
# Строка №172
# Строка №173
# Строка №174
# Строка №175
# Строка №176
# Строка №177
# Строка №178
# Строка №179
# Строка №180
# Строка №181
# Строка №182
# Строка №183
# Строка №184
# Строка №185
# Строка №186
# Строка №187
# Строка №188
# Строка №189
# Строка №190
# Строка №191
# Строка №192
# Строка №193
# Строка №194
# Строка №195
# Строка №196
# Строка №197
# Строка №198
# Строка №199
# Строка №200
# Строка №201
# Строка №202
# Строка №203
# Строка №204
# Строка №205
# Строка №206
# Строка №207
# Строка №208
# Строка №209
# Строка №210
# Строка №211
# Строка №212
# Строка №213
# Строка №214
# Строка №215
# Строка №216
# Строка №217
# Строка №218
# Строка №219
# Строка №220
# Строка №221
# Строка №222
# Строка №223
# Строка №224
# Строка №225
# Строка №226
# Строка №227
# Строка №228
# Строка №229
# Строка №230
# Строка №231
# Строка №232
# Строка №233
# Строка №234
# Строка №235
# Строка №236
# Строка №237
# Строка №238
# Строка №239
# Строка №240
# Строка №241
# Строка №242
# Строка №243
# Строка №244
# Строка №245
# Строка №246
# Строка №247
# Строка №248
# Строка №249
# Строка №250
# Строка №251
# Строка №252
# Строка №253
# Строка №254
# Строка №255
# Строка №256
# Строка №257
# Строка №258
# Строка №259
# Строка №260
# Строка №261
# Строка №262
# Строка №263
# Строка №264
# Строка №265
# Строка №266
# Строка №267
# Строка №268
# Строка №269
# Строка №270
# Строка №271
# Строка №272
# Строка №273
# Строка №274
# Строка №275
# Строка №276
# Строка №277
# Строка №278
# Строка №279
# Строка №280
# Строка №281
# Строка №282
# Строка №283
# Строка №284
# Строка №285
# Строка №286
# Строка №287
# Строка №288
# Строка №289
# Строка №290
# Строка №291
# Строка №292
# Строка №293
# Строка №294
# Строка №295
# Строка №296
# Строка №297
# Строка №298
# Строка №299
# Строка №300
# Строка №301
# Строка №302
# Строка №303
# Строка №304
# Строка №305
# Строка №306
# Строка №307
# Строка №308
# Строка №309
# Строка №310
# Строка №311
# Строка №312
# Строка №313
# Строка №314
# Строка №315
# Строка №316
# Строка №317
# Строка №318
# Строка №319
# Строка №320
# Строка №321
# Строка №322
# Строка №323
# Строка №324
# Строка №325
# Строка №326
# Строка №327
# Строка №328
# Строка №329
# Строка №330
# Строка №331
# Строка №332
# Строка №333
# Строка №334
# Строка №335
# Строка №336
# Строка №337
# Строка №338
# Строка №339
# Строка №340
# Строка №341
# Строка №342
# Строка №343
# Строка №344
# Строка №345
# Строка №346
# Строка №347
# Строка №348
# Строка №349
# Строка №350
# Строка №351
# Строка №352
# Строка №353
# Строка №354
# Строка №355
# Строка №356
# Строка №357
# Строка №358
# Строка №359
# Строка №360
# Строка №361
# Строка №362
# Строка №363
# Строка №364
# Строка №365
# Строка №366
# Строка №367
# Строка №368
# Строка №369
# Строка №370
# Строка №371
# Строка №372
# Строка №373
# Строка №374
# Строка №375
# Строка №376
# Строка №377
# Строка №378
# Строка №379
# Строка №380
# Строка №381
# Строка №382
# Строка №383
# Строка №384
# Строка №385
# Строка №386
# Строка №387
# Строка №388
# Строка №389
# Строка №390
# Строка №391
# Строка №392
# Строка №393
# Строка №394
# Строка №395
# Строка №396
# Строка №397
# Строка №398
# Строка №399
# Строка №400
# Строка №401
# Строка №402
# Строка №403
# Строка №404
# Строка №405
# Строка №406
# Строка №407
# Строка №408
# Строка №409
# Строка №410
# Строка №411
# Строка №412
# Строка №413
# Строка №414
# Строка №415
# Строка №416
# Строка №417
# Строка №418
# Строка №419
# Строка №420
# Строка №421
# Строка №422
# Строка №423
# Строка №424
# Строка №425
# Строка №426
# Строка №427
# Строка №428
# Строка №429
# Строка №430
# Строка №431
# Строка №432
# Строка №433
# Строка №434
# Строка №435
# Строка №436
# Строка №437
# Строка №438
# Строка №439
# Строка №440
# Строка №441
# Строка №442
# Строка №443
# Строка №444
# Строка №445
# Строка №446
# Строка №447
# Строка №448
# Строка №449
# Строка №450
# Строка №451
# Строка №452
# Строка №453
# Строка №454
# Строка №455
# Строка №456
# Строка №457
# Строка №458
# Строка №459
# Строка №460
# Строка №461
# Строка №462
# Строка №463
# Строка №464
# Строка №465
# Строка №466
# Строка №467
# Строка №468
# Строка №469
# Строка №470
# Строка №471
# Строка №472
# Строка №473
# Строка №474
# Строка №475
# Строка №476
# Строка №477
# Строка №478
# Строка №479
# Строка №480
# Строка №481
# Строка №482
# Строка №483
# Строка №484
# Строка №485
# Строка №486
# Строка №487
# Строка №488
# Строка №489
# Строка №490
# Строка №491
# Строка №492
# Строка №493
# Строка №494
# Строка №495
# Строка №496
# Строка №497
# Строка №498
# Строка №499
# Строка №500
# Строка №501
# Строка №502
# Строка №503
# Строка №504
# Строка №505
# Строка №506
# Строка №507
# Строка №508
# Строка №509
# Строка №510
# Строка №511
# Строка №512
# Строка №513
# Строка №514
# Строка №515
# Строка №516
# Строка №517
# Строка №518
# Строка №519
# Строка №520
# Строка №521
# Строка №522
# Строка №523
# Строка №524
# Строка №525
# Строка №526
# Строка №527
# Строка №528
# Строка №529
# Строка №530
# Строка №531
# Строка №532
# Строка №533
# Строка №534
# Строка №535
# Строка №536
# Строка №537
# Строка №538
# Строка №539
# Строка №540
# Строка №541
# Строка №542
# Строка №543
# Строка №544
# Строка №545
# Строка №546
# Строка №547
# Строка №548
# Строка №549
# Строка №550
# Строка №551
# Строка №552
# Строка №553
# Строка №554
# Строка №555
# Строка №556
# Строка №557
# Строка №558
# Строка №559
# Строка №560
# Строка №561
# Строка №562
# Строка №563
# Строка №564
# Строка №565
# Строка №566
# Строка №567
# Строка №568
# Строка №569
# Строка №570
# Строка №571
# Строка №572
# Строка №573
# Строка №574
# Строка №575
# Строка №576
# Строка №577
# Строка №578
# Строка №579
# Строка №580
# Строка №581
# Строка №582
# Строка №583
# Строка №584
# Строка №585
# Строка №586
# Строка №587
# Строка №588
# Строка №589
# Строка №590
# Строка №591
# Строка №592
# Строка №593
# Строка №594
# Строка №595
# Строка №596
# Строка №597
# Строка №598
# Строка №599
# Строка №600
# Строка №601
# Строка №602
# Строка №603
# Строка №604
# Строка №605
# Строка №606
# Строка №607
# Строка №608
# Строка №609
# Строка №610
# Строка №611
# Строка №612
# Строка №613
# Строка №614
# Строка №615
# Строка №616
# Строка №617
# Строка №618
# Строка №619
# Строка №620
# Строка №621
# Строка №622
# Строка №623
# Строка №624
# Строка №625
# Строка №626
# Строка №627
# Строка №628
# Строка №629
# Строка №630
# Строка №631
# Строка №632
# Строка №633
# Строка №634
# Строка №635
# Строка №636
# Строка №637
# Строка №638
# Строка №639
# Строка №640
# Строка №641
# Строка №642
# Строка №643
# Строка №644
# Строка №645
# Строка №646
# Строка №647
# Строка №648
# Строка №649
# Строка №650
# Строка №651
# Строка №652
# Строка №653
# Строка №654
# Строка №655
# Строка №656
# Строка №657
# Строка №658
# Строка №659
# Строка №660
# Строка №661
# Строка №662
# Строка №663
# Строка №664
# Строка №665
# Строка №666
# Строка №667
# Строка №668
# Строка №669
# Строка №670
# Строка №671
# Строка №672
# Строка №673
# Строка №674
# Строка №675
# Строка №676
# Строка №677
# Строка №678
# Строка №679
# Строка №680
# Строка №681
# Строка №682
# Строка №683
# Строка №684
# Строка №685
# Строка №686
# Строка №687
# Строка №688
# Строка №689
# Строка №690
# Строка №691
# Строка №692
# Строка №693
# Строка №694
# Строка №695
# Строка №696
# Строка №697
# Строка №698
# Строка №699
# Строка №700
# Строка №701
# Строка №702
# Строка №703
# Строка №704
# Строка №705
# Строка №706
# Строка №707
# Строка №708
# Строка №709
# Строка №710
# Строка №711
# Строка №712
# Строка №713
# Строка №714
# Строка №715
# Строка №716
# Строка №717
# Строка №718
# Строка №719
# Строка №720
# Строка №721
# Строка №722
# Строка №723
# Строка №724
# Строка №725
# Строка №726
# Строка №727
# Строка №728
# Строка №729
# Строка №730
# Строка №731
# Строка №732
# Строка №733
# Строка №734
# Строка №735
# Строка №736
# Строка №737
# Строка №738
# Строка №739
# Строка №740
# Строка №741
# Строка №742
# Строка №743
# Строка №744
# Строка №745
# Строка №746
# Строка №747
# Строка №748
# Строка №749
# Строка №750
# Строка №751
# Строка №752
# Строка №753
# Строка №754
# Строка №755
# Строка №756
# Строка №757
# Строка №758
# Строка №759
# Строка №760
# Строка №761
# Строка №762
# Строка №763
# Строка №764
# Строка №765
# Строка №766
# Строка №767
# Строка №768
# Строка №769
# Строка №770
# Строка №771
# Строка №772
# Строка №773
# Строка №774
# Строка №775
# Строка №776
# Строка №777
# Строка №778
# Строка №779
# Строка №780
# Строка №781
# Строка №782
# Строка №783
# Строка №784
# Строка №785
# Строка №786
# Строка №787
# Строка №788
# Строка №789
# Строка №790
# Строка №791
# Строка №792
# Строка №793
# Строка №794
# Строка №795
# Строка №796
# Строка №797
# Строка №798
# Строка №799
# Строка №800
# Строка №801
# Строка №802
# Строка №803
# Строка №804
# Строка №805
# Строка №806
# Строка №807
# Строка №808
# Строка №809
# Строка №810
# Строка №811
# Строка №812
# Строка №813
# Строка №814
# Строка №815
# Строка №816
# Строка №817
# Строка №818
# Строка №819
# Строка №820
# Строка №821
# Строка №822
# Строка №823
# Строка №824
# Строка №825
# Строка №826
# Строка №827
# Строка №828
# Строка №829
# Строка №830
# Строка №831
# Строка №832
# Строка №833
# Строка №834
# Строка №835
# Строка №836
# Строка №837
# Строка №838
# Строка №839
# Строка №840
# Строка №841
# Строка №842
# Строка №843
# Строка №844
# Строка №845
# Строка №846
# Строка №847
# Строка №848
# Строка №849
# Строка №850
# Строка №851
# Строка №852
# Строка №853
# Строка №854
# Строка №855
# Строка №856
# Строка №857
# Строка №858
# Строка №859
# Строка №860
# Строка №861
# Строка №862
# Строка №863
# Строка №864
# Строка №865
# Строка №866
# Строка №867
# Строка №868
# Строка №869
# Строка №870
# Строка №871
# Строка №872
# Строка №873
# Строка №874
# Строка №875
# Строка №876
# Строка №877
# Строка №878
# Строка №879
# Строка №880
# Строка №881
# Строка №882
# Строка №883
# Строка №884
# Строка №885
# Строка №886
# Строка №887
# Строка №888
# Строка №889
# Строка №890
# Строка №891
# Строка №892
# Строка №893
# Строка №894
# Строка №895
# Строка №896
# Строка №897
# Строка №898
# Строка №899
# Строка №900
# Строка №901
# Строка №902
# Строка №903
# Строка №904
# Строка №905
# Строка №906
# Строка №907
# Строка №908
# Строка №909
# Строка №910
# Строка №911
# Строка №912
# Строка №913
# Строка №914
# Строка №915
# Строка №916
# Строка №917
# Строка №918
# Строка №919
# Строка №920
# Строка №921
# Строка №922
# Строка №923
# Строка №924
# Строка №925
# Строка №926
# Строка №927
# Строка №928
# Строка №929
# Строка №930
# Строка №931
# Строка №932
# Строка №933
# Строка №934
# Строка №935
# Строка №936
# Строка №937
# Строка №938
# Строка №939
# Строка №940
# Строка №941
# Строка №942
# Строка №943
# Строка №944
# Строка №945
# Строка №946
# Строка №947
# Строка №948
# Строка №949
# Строка №950
# Строка №951
# Строка №952
# Строка №953
# Строка №954
# Строка №955
# Строка №956
# Строка №957
# Строка №958
# Строка №959
# Строка №960
# Строка №961
# Строка №962
# Строка №963
# Строка №964
# Строка №965
# Строка №966
# Строка №967
# Строка №968
# Строка №969
# Строка №970
# Строка №971
# Строка №972
# Строка №973
# Строка №974
# Строка №975
# Строка №976
# Строка №977
# Строка №978
# Строка №979
# Строка №980
# Строка №981
# Строка №982
# Строка №983
# Строка №984
# Строка №985
# Строка №986
# Строка №987
# Строка №988
# Строка №989
# Строка №990
# Строка №991
# Строка №992
# Строка №993
# Строка №994
# Строка №995
# Строка №996
# Строка №997
# Строка №998
# Строка №999
# Строка №1000
# Строка №1001
# Строка №1002
# Строка №1003
# Строка №1004
# Строка №1005
# Строка №1006
# Строка №1007
# Строка №1008
# Строка №1009
# Строка №1010
# Строка №1011
# Строка №1012
# Строка №1013
# Строка №1014
# Строка №1015
# Строка №1016
# Строка №1017
# Строка №1018
# Строка №1019
# Строка №1020
# Строка №1021
# Строка №1022
# Строка №1023
# Строка №1024
# Строка №1025
# Строка №1026
# Строка №1027
# Строка №1028
# Строка №1029
# Строка №1030
# Строка №1031
# Строка №1032
# Строка №1033
# Строка №1034
# Строка №1035
# Строка №1036
# Строка №1037
# Строка №1038
# Строка №1039
# Строка №1040
# Строка №1041
# Строка №1042
# Строка №1043
# Строка №1044
# Строка №1045
# Строка №1046
# Строка №1047
# Строка №1048
# Строка №1049
# Строка №1050
# Строка №1051
# Строка №1052
# Строка №1053
# Строка №1054
# Строка №1055
# Строка №1056
# Строка №1057
# Строка №1058
# Строка №1059
# Строка №1060
# Строка №1061
# Строка №1062
# Строка №1063
# Строка №1064
# Строка №1065
# Строка №1066
# Строка №1067
# Строка №1068
# Строка №1069
# Строка №1070
# Строка №1071
# Строка №1072
# Строка №1073
# Строка №1074
# Строка №1075
# Строка №1076
# Строка №1077
# Строка №1078
# Строка №1079
# Строка №1080
# Строка №1081
# Строка №1082
# Строка №1083
# Строка №1084
# Строка №1085
# Строка №1086
# Строка №1087
# Строка №1088
# Строка №1089
# Строка №1090
# Строка №1091
# Строка №1092
# Строка №1093
# Строка №1094
# Строка №1095
# Строка №1096
# Строка №1097
# Строка №1098
# Строка №1099
# Строка №1100
# Строка №1101
# Строка №1102
# Строка №1103
# Строка №1104
# Строка №1105
# Строка №1106
# Строка №1107
# Строка №1108
# Строка №1109
# Строка №1110
# Строка №1111
# Строка №1112
# Строка №1113
# Строка №1114
# Строка №1115
# Строка №1116
# Строка №1117
# Строка №1118
# Строка №1119
# Строка №1120
# Строка №1121
# Строка №1122
# Строка №1123
# Строка №1124
# Строка №1125
# Строка №1126
# Строка №1127
# Строка №1128
# Строка №1129
# Строка №1130
# Строка №1131
# Строка №1132
# Строка №1133
# Строка №1134
# Строка №1135
# Строка №1136
# Строка №1137
# Строка №1138
# Строка №1139
# Строка №1140
# Строка №1141
# Строка №1142
# Строка №1143
# Строка №1144
# Строка №1145
# Строка №1146
# Строка №1147
# Строка №1148
# Строка №1149
# Строка №1150
# Строка №1151
# Строка №1152
# Строка №1153
# Строка №1154
# Строка №1155
# Строка №1156
# Строка №1157
# Строка №1158
# Строка №1159
# Строка №1160
# Строка №1161
# Строка №1162
# Строка №1163
# Строка №1164
# Строка №1165
# Строка №1166
# Строка №1167
# Строка №1168
# Строка №1169
# Строка №1170
# Строка №1171
# Строка №1172
# Строка №1173
# Строка №1174
# Строка №1175
# Строка №1176
# Строка №1177
# Строка №1178
# Строка №1179
# Строка №1180
# Строка №1181
# Строка №1182
# Строка №1183
# Строка №1184
# Строка №1185
# Строка №1186
# Строка №1187
# Строка №1188

# %%
DATA_PATH = '/Users/andrey/PycharmProjects/DataMiningProjects/data'

# %%
# 13.2 Дизлайки. Цикл. По ошибкам

indeseS = errorS
errorS = []

for j in indeseS:
    time.sleep(1)
    print(f'Строка №{j}')
    try:
        videos_df.loc[j, "statistics.dislikesCount"] = getDislikes(videos_df['id'][j])
    except:
        print(f'Ошибка в строке {j}')
        errorS.append(j)
# Out:
# Строка №74
# Ошибка в строке 74
# Строка №1085
# Ошибка в строке 1085

# %%
display(videos_df)
#df_supplemented.to_excel(f'Про_{type_content}.xlsx')
# Out:
#                kind                         etag           id  \
# 0     youtube#video  hFWHeWO-R7oU4c2XL_XGUFSW0Ro  Wi49rKRM85U
# 1     youtube#video  dH5eRX5ktvZc5h6hZepKAsK6zSo  1ErvLvQoYxc
# 2     youtube#video  VAaYvq0w2V6n-a6E6upg2A1iJbE  aiY0ymL25Pw
# 3     youtube#video  Xu0qxfp0-q2X2DrGsPlfAAn6nqM  JA9E4TCVsDU
# 4     youtube#video  1G4hAX30sQ9cKXA2lX2UD6wUbuY  NAeXVpMTiT4
# ...             ...                          ...          ...
# 1310  youtube#video  wnooTiYmWg1RbmxHA16uQ7ZJhKQ  QdFBJTWrXGQ
# 1311  youtube#video  dDMWPkWbXFHTb5JMpjUgBZvHIsU  WDaSYoc6Cbo
# 1312  youtube#video  66bPDJ5bsTweNPI7uFprdPd1Zt8  E2xdveEfT2Y
# 1313  youtube#video  Lm84VayHJd3jOM_UqYjUm5LKvf4  VcnXkDXeF-Y
# 1314  youtube#video  Nph-A8nfl1n8srDfyshqsFSYfvg  mw1vV8n1Ey0
#
#        snippet.publishedAt         snippet.channelId  \
# 0     2022-06-20T12:57:48Z  UCphnZS52v_lkv5RSl5n70tQ
# 1     2019-03-21T10:23:49Z  UC6C0oFYlpKkFGG-ykqM4fYw
# 2     2021-08-20T08:51:18Z  UCiT7bPorr4rKJU8WFBZA9Og
# 3     2015-12-06T14:30:40Z  UCNazbf-kLY6E8TO_o48ZExQ
# 4     2018-04-20T15:19:56Z  UCmXGqfEsluA1fID55bVexjw
# ...                    ...                       ...
# 1310  2022-04-06T09:05:51Z  UCBXqiEMJMVTXeQfcZ2M6sow
# 1311  2023-01-05T04:42:56Z  UCM7-Frn5Zz4aXplhkaGI5zg
# 1312  2022-10-17T14:14:46Z  UCbOs6A4SJYanjQXsooKi0Fg
# 1313  2022-11-18T16:07:00Z  UCM7-Frn5Zz4aXplhkaGI5zg
# 1314  2023-02-28T10:34:33Z  UC5miehRccdKBd8yxSl3By0w
#
#                                           snippet.title  \
# 0     한국인들은 절대 안사는 화장품 КОСМЕТИКА КОТОРАЯ КОРЕЯНКИ ВО...
# 1     ТЫ ДОЛЖНА ЭТО ПОПРОБОВАТЬ! ЛУЧШАЯ КОРЕЙСКАЯ КО...
# 2     РЕАКЦИЯ дерматолога: 10 этапов корейского уход...
# 3     КАК Я ИСПОРТИЛА КОЖУ: КОРЕЙСКАЯ КОСМЕТИКА\Tony...
# 4     🇰🇷 НЕВЕРОЯТНАЯ КОРЕЙСКАЯ КОСМЕТИКА! Топовые шт...
# ...                                                 ...
# 1310               Atomy The Fame | Корейская косметика
# 1311  ПЕНКА ДЛЯ УМЫВАНИЯ ЛИЦА КОРЕЙСКАЯ КОСМЕТИКА ☎️...
# 1312  КОРЕЙСКИЙ МАКИЯЖ ДЛЯ НАЧИНАЮЩИХ 🤩😍    #тень #м...
# 1313  КОРЕЙСКАЯ КОСМЕТИКА №1 📱+998935594555✍🏻 ТЕЛЕГР...
# 1314            АСМР СТАНДОФФ 2 #6 100 ПОДПИСЧИКОВ УРА!
#
#                                     snippet.description  \
# 0     ⚫подписаться: https://goo.gl/3QbeUf\n---------...
# 1     Хорошие мои, сегодня я расскажу вам про свой к...
# 2     Мой телеграм:\nhttps://t.me/dr_amina_pirmanova...
# 3     Привет! Корейская косметика снова набирает обо...
# 4     Магазин корейской косметики https://goo.gl/UJG...
# ...                                                 ...
# 1310  Для заказа заполняйте анкету для регистрации н...
# 1311                                                NaN
# 1312                                                NaN
# 1313                                                NaN
# 1314  АСМР СТАНДОФФ 2 #6 100 ПОДПИСЧИКОВ УРА!\n\nесл...
#
#                       snippet.thumbnails.default.url  \
# 0     https://i.ytimg.com/vi/Wi49rKRM85U/default.jpg
# 1     https://i.ytimg.com/vi/1ErvLvQoYxc/default.jpg
# 2     https://i.ytimg.com/vi/aiY0ymL25Pw/default.jpg
# 3     https://i.ytimg.com/vi/JA9E4TCVsDU/default.jpg
# 4     https://i.ytimg.com/vi/NAeXVpMTiT4/default.jpg
# ...                                              ...
# 1310  https://i.ytimg.com/vi/QdFBJTWrXGQ/default.jpg
# 1311  https://i.ytimg.com/vi/WDaSYoc6Cbo/default.jpg
# 1312  https://i.ytimg.com/vi/E2xdveEfT2Y/default.jpg
# 1313  https://i.ytimg.com/vi/VcnXkDXeF-Y/default.jpg
# 1314  https://i.ytimg.com/vi/mw1vV8n1Ey0/default.jpg
#
#       snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                                  120                                 90
# 1                                  120                                 90
# 2                                  120                                 90
# 3                                  120                                 90
# 4                                  120                                 90
# ...                                ...                                ...
# 1310                               120                                 90
# 1311                               120                                 90
# 1312                               120                                 90
# 1313                               120                                 90
# 1314                               120                                 90
#
#       ... statistics.likeCount  statistics.favoriteCount  \
# 0     ...              54006.0                         0
# 1     ...              11041.0                         0
# 2     ...              31842.0                         0
# 3     ...               2955.0                         0
# 4     ...              12749.0                         0
# ...   ...                  ...                       ...
# 1310  ...                  9.0                         0
# 1311  ...                  2.0                         0
# 1312  ...                 78.0                         0
# 1313  ...                  1.0                         0
# 1314  ...                 40.0                         0
#
#       statistics.commentCount  \
# 0                      1065.0
# 1                       378.0
# 2                      1777.0
# 3                       324.0
# 4                       687.0
# ...                       ...
# 1310                      1.0
# 1311                      0.0
# 1312                      0.0
# 1313                      0.0
# 1314                     24.0
#
#                                        player.embedHtml  \
# 0     <iframe width="480" height="270" src="//www.yo...
# 1     <iframe width="480" height="270" src="//www.yo...
# 2     <iframe width="480" height="270" src="//www.yo...
# 3     <iframe width="480" height="270" src="//www.yo...
# 4     <iframe width="480" height="270" src="//www.yo...
# ...                                                 ...
# 1310  <iframe width="480" height="270" src="//www.yo...
# 1311  <iframe width="480" height="270" src="//www.yo...
# 1312  <iframe width="480" height="270" src="//www.yo...
# 1313  <iframe width="480" height="270" src="//www.yo...
# 1314  <iframe width="480" height="270" src="//www.yo...
#
#                            topicDetails.topicCategories  \
# 0     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 2     ['https://en.wikipedia.org/wiki/Health', 'http...
# 3     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 4     ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# ...                                                 ...
# 1310  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1311  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1312  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1313  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 1314  ['https://en.wikipedia.org/wiki/Action_game', ...
#
#       snippet.defaultLanguage liveStreamingDetails.actualStartTime  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
# ...                       ...                                  ...
# 1310                      NaN                                  NaN
# 1311                      NaN                                  NaN
# 1312                      NaN                                  NaN
# 1313                      NaN                                  NaN
# 1314                      NaN                                  NaN
#
#       liveStreamingDetails.actualEndTime  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1310                                 NaN
# 1311                                 NaN
# 1312                                 NaN
# 1313                                 NaN
# 1314                                 NaN
#
#       liveStreamingDetails.scheduledStartTime statistics.dislikesCount
# 0                                         NaN                    595.0
# 1                                         NaN                    192.0
# 2                                         NaN                    279.0
# 3                                         NaN                    555.0
# 4                                         NaN                    397.0
# ...                                       ...                      ...
# 1310                                      NaN                      0.0
# 1311                                      NaN                      0.0
# 1312                                      NaN                      0.0
# 1313                                      NaN                      0.0
# 1314                                      NaN                      0.0
#
# [1315 rows x 40 columns]

# %%
videos_df.to_excel(DATA_PATH + '/Video_characteristics_KBeauty.xlsx', index=False)
